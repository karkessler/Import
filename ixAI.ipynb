# %% [markdown]
# <a href="https://colab.research.google.com/github/karkessler/Import/blob/master/ixAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install albumentations
import numpy as np
import cv2
from matplotlib import pyplot as plt
from IPython.display import display, HTML 

from albumentations import *
from google.colab import drive

def show_img(img, figsize=(8, 8)):
    fig, ax = plt.subplots(figsize=figsize)
    ax.grid(False)
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.imshow(img)
    plt.imshow(img)

def image_resize(image, width = None, height = None, inter = cv2.INTER_AREA):
    # initialize the dimensions of the image to be resized and
    # grab the image size
    dim = None
    (h, w) = image.shape[:2]

    # if both the width and height are None, then return the
    # original image
    if width is None and height is None:
        return image

    # check to see if the width is None
    if width is None:
        # calculate the ratio of the height and construct the
        # dimensions
        r = height / float(h)
        dim = (int(w * r), height)

    # otherwise, the height is None
    else:
        # calculate the ratio of the width and construct the
        # dimensions
        r = width / float(w)
        dim = (width, int(h * r))

    # resize the image
    resized = cv2.resize(image, dim, interpolation = inter)

    # return the resized image
    return resized

print("ok")
# Out:
# ok

# %%
#drive.mount('/content/drive')
# !ls -la 'drive/My Drive/My Drive/data/ix-tut-raw'

c3po_img = cv2.imread('drive/My Drive/My Drive/data/ix-tut-raw/Passbild.jpg')
c3po_img = cv2.cvtColor(c3po_img, cv2.COLOR_BGR2RGB)
c3po_img = image_resize(c3po_img, height=416)
show_img(c3po_img)

aug = CenterCrop(416,305, p=1.0)
c3po_img = aug.apply(c3po_img)
show_img(c3po_img)

alpha = 2.2
aug = RandomBrightness(p=1)
c3po_img2 = aug.apply(c3po_img, alpha=alpha)
show_img(c3po_img2)

state = "enabled" 
aug = HorizontalFlip(p=1)
c3po_img3 = aug.apply(c3po_img) if state == 'enabled' else c3po_img
show_img(c3po_img3)

state = "enabled" 
aug = VerticalFlip(p=1)
c3po_img4 = aug.apply(c3po_img) if state == 'enabled' else c3po_img
show_img(c3po_img4)

angle = 90 
aug = RandomRotate90(p=0.5)
c3po_img5 = aug.apply(c3po_img, factor=angle // 90)
show_img(c3po_img5)

aug = ElasticTransform(alpha=203, sigma=25, alpha_affine=25, p=1.0)
c3po_img10 = aug.apply(c3po_img)
show_img(c3po_img10)

aug = Blur(p=0.5, blur_limit=7)
c3po_img15 = aug.apply(c3po_img10)
show_img(c3po_img15)

aug = ToGray(p=0.5)
c3po_img13 = aug.apply(c3po_img)
show_img(c3po_img13)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-ac11e0a556bf> in <module>()
#      50
#      51 # Alle Bilddateien mit der Endung jpg
# ---> 52 raw_image_lst = glob.glob(raw_images+'*.jpg')
#      53
#      54 print(f"Liste enthält {len(raw_image_lst)} Bilder")
#
# NameError: name 'glob' is not defined

# %%
from __future__ import division

import os
import glob
import numpy as np
import cv2
from matplotlib import pyplot as plt
from IPython.display import display, HTML 

from albumentations import *
from google.colab import drive

# Eigene Fotos
raw_images = '/content/drive/My Drive/My Drive/data/ix-tut-raw/'

# Ausgabeverzeichnis
processed_images = '/content/drive/My Drive/My Drive/data/ix-tut-processed/'

# Alle Bilddateien mit der Endung jpg
raw_image_lst = glob.glob(raw_images+'*.jpg')

print(f"Liste enthält {len(raw_image_lst)} Bilder")
# Out:
# Liste enthält 1 Bilder

# %%
# !git clone https://github.com/rawar/ix-tut-yolov3-data
# !ls -la

# !ls -la 'ix-tut-yolov3-data/data'
# Out:
# Cloning into 'ix-tut-yolov3-data'...
# remote: Enumerating objects: 2672, done.
# remote: Total 2672 (delta 0), reused 0 (delta 0), pack-reused 2672
# Receiving objects: 100% (2672/2672), 52.62 MiB | 15.33 MiB/s, done.
# Resolving deltas: 100% (252/252), done.
# total 24
# drwxr-xr-x 1 root root 4096 Jan 10 06:11 .
# drwxr-xr-x 1 root root 4096 Jan 10 06:04 ..
# drwxr-xr-x 1 root root 4096 Jan  6 18:10 .config
# drwx------ 5 root root 4096 Jan 10 06:06 drive
# drwxr-xr-x 8 root root 4096 Jan 10 06:11 ix-tut-yolov3-data
# drwxr-xr-x 1 root root 4096 Jan  6 18:10 sample_data
# total 64172
# drwxr-xr-x 2 root root 139264 Jan 10 06:11 .
# drwxr-xr-x 8 root root   4096 Jan 10 06:11 ..
# -rw-r--r-- 1 root root  15874 Jan 10 06:11 c3po_0001_elastic_alpha.jpg
# -rw-r--r-- 1 root root  26701 Jan 10 06:11 c3po_0001_elastic_bight.jpg
# -rw-r--r-- 1 root root  20521 Jan 10 06:11 c3po_0001_elastic_blur.jpg
# -rw-r--r-- 1 root root  27016 Jan 10 06:11 c3po_0001_elastic_bright.jpg
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
